# %% [markdown]
# <a href="https://colab.research.google.com/github/anggad08/DMC_ML_COURSE/blob/main/MLTRABAJO_FINAL_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scikit-Learn
import sklearn
assert sklearn.__version__ >= "0.20"

# Imports comunes
import pandas as pd
import numpy as np
import os

# Configuración de tamaño de gráficos matplotlib
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Ignore las advertencias poco útiles
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %%
# Cargar Data
import pandas as pd
pddf = pd.read_csv("winequality-white.csv")
pddf.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
pddf.shape
# Out:
# (4898, 1)

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Verificar la ubicación del archivo
file_path = 'winequality-white.csv'
if not os.path.exists(file_path):
    print(f"Error: El archivo '{file_path}' no se encuentra en el directorio actual. Los archivos disponibles son:")
    print(os.listdir())
else:
    # Cargar el dataset con el delimitador correcto
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")

    # Mostrar las primeras filas del dataset
    print(pddf.head())

    # Verificar las columnas del DataFrame
    print("Columnas del DataFrame:", pddf.columns)

    # Usar el nombre correcto de la columna (suponiendo que es 'quality')
    if 'quality' not in pddf.columns:
        print("Error: La columna 'quality' no existe en el DataFrame. Las columnas disponibles son:")
        print(pddf.columns)
    else:
        sns.set(style="whitegrid", color_codes=True)
        sns.set(rc={'figure.figsize':(10,6)})

        plt.figure(figsize=(10,6))
        sns.countplot(x='quality', data=pddf, palette='hls')
        plt.title('Distribución de la Calidad del Vino')
        plt.xlabel('Quality')
        plt.ylabel('Frecuencia')
        plt.show()
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='quality', data=pddf, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# <ipython-input-23-0b6398accf7f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='quality', data=pddf, palette='hls')

# %%
import pandas as pd

# Cargar el dataset con el delimitador correcto
pddf = pd.read_csv('winequality-white.csv', delimiter=';')

# Contar el número de instancias de cada calificación de calidad
quality_counts = pddf['quality'].value_counts().sort_index()
print(quality_counts)
# Out:
# quality
# 3      20
# 4     163
# 5    1457
# 6    2198
# 7     880
# 8     175
# 9       5
# Name: count, dtype: int64

# %%
import pandas as pd

# Cargar el dataset
file_path = 'winequality-white.csv'
try:
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encuentra en la ruta especificada.")
    raise
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    raise

# Verificar las primeras filas del dataset
print(pddf.head())

# Verificar las columnas del DataFrame
print("Columnas del DataFrame:", pddf.columns)

# Verificar si hay valores NaN
print("Valores NaN en el dataset:\n", pddf.isna().sum())

# Eliminar filas con valores NaN (si es necesario)
pddf = pddf.dropna()

# Verificar que todas las columnas sean numéricas
print("Tipos de datos en el DataFrame:\n", pddf.dtypes)

# Si hay columnas no numéricas, convertirlas o eliminarlas (si es necesario)
# pddf = pddf.apply(pd.to_numeric, errors='coerce')

# Verificar nuevamente después de la limpieza
print("Verificación después de la limpieza:")
print("Valores NaN en el dataset:\n", pddf.isna().sum())
print("Tipos de datos en el DataFrame:\n", pddf.dtypes)
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
# Verificar el número de muestras por clase en el conjunto de entrenamiento
print(y_train.value_counts())
# Out:
# quality
# 6    1538
# 5    1020
# 7     616
# 8     122
# 4     114
# 3      14
# 9       4
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Cargar el dataset
file_path = 'winequality-white.csv'
try:
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encuentra en la ruta especificada.")
    raise
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    raise

# Verificar las primeras filas del dataset
print(pddf.head())

# Verificar las columnas del DataFrame
print("Columnas del DataFrame:", pddf.columns)

# Visualizar la distribución de la variable objetivo 'quality'
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='quality', data=pddf, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Separar características y etiquetas
X = pddf.drop('quality', axis=1)
y = pddf['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba con estratificación
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Verificar el número de muestras por clase en el conjunto de entrenamiento
print(y_train.value_counts())

# Aplicar SMOTE para balancear el conjunto de entrenamiento
# Ajustar k_neighbors basado en el número de muestras en la clase minoritaria más pequeña
smote = SMOTE(random_state=42, k_neighbors=2)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Entrenar el modelo con datos balanceados usando SMOTE
clf_smote = RandomForestClassifier(random_state=42)
clf_smote.fit(X_train_smote, y_train_smote)

# Predecir y evaluar el modelo balanceado con SMOTE
y_pred_smote = clf_smote.predict(X_test)
print("Resultados para SMOTE:")
print(classification_report(y_test, y_pred_smote))

# Aplicar otras técnicas de balanceo si es necesario
# Submuestreo
rus = RandomUnderSampler(random_state=42)
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)
clf_rus = RandomForestClassifier(random_state=42)
clf_rus.fit(X_train_rus, y_train_rus)
y_pred_rus = clf_rus.predict(X_test)
print("Resultados para Submuestreo:")
print(classification_report(y_test, y_pred_rus))

# Combinación SMOTEENN
smote_enn = SMOTEENN(random_state=42)
X_train_smoteenn, y_train_smoteenn = smote_enn.fit_resample(X_train, y_train)
clf_smoteenn = RandomForestClassifier(random_state=42)
clf_smoteenn.fit(X_train_smoteenn, y_train_smoteenn)
y_pred_smoteenn = clf_smoteenn.predict(X_test)
print("Resultados para SMOTEENN:")
print(classification_report(y_test, y_pred_smoteenn))
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Cargar el dataset
file_path = 'winequality-white.csv'
try:
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encuentra en la ruta especificada.")
    raise
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    raise

# Verificar las primeras filas del dataset
print(pddf.head())

# Verificar las columnas del DataFrame
print("Columnas del DataFrame:", pddf.columns)

# Visualizar la distribución de la variable objetivo 'quality'
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='quality', data=pddf, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Separar características y etiquetas
X = pddf.drop('quality', axis=1)
y = pddf['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba con estratificación
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Verificar el número de muestras por clase en el conjunto de entrenamiento
print(y_train.value_counts())

# Aplicar SMOTE para balancear el conjunto de entrenamiento
# Ajustar k_neighbors basado en el número de muestras en la clase minoritaria más pequeña
smote = SMOTE(random_state=42, k_neighbors=2)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Entrenar el modelo con datos balanceados usando SMOTE
clf_smote = RandomForestClassifier(random_state=42)
clf_smote.fit(X_train_smote, y_train_smote)

# Predecir y evaluar el modelo balanceado con SMOTE
y_pred_smote = clf_smote.predict(X_test)
print("Resultados para SMOTE:")
print(classification_report(y_test, y_pred_smote))

# Aplicar otras técnicas de balanceo si es necesario
# Submuestreo
rus = RandomUnderSampler(random_state=42)
X_train_rus, y_train_rus = rus.fit_resample(X_train, y_train)
clf_rus = RandomForestClassifier(random_state=42)
clf_rus.fit(X_train_rus, y_train_rus)
y_pred_rus = clf_rus.predict(X_test)
print("Resultados para Submuestreo:")
print(classification_report(y_test, y_pred_rus))

# Combinación SMOTEENN
try:
    smote_enn = SMOTEENN(random_state=42, smote=SMOTE(k_neighbors=2))
    X_train_smoteenn, y_train_smoteenn = smote_enn.fit_resample(X_train, y_train)
    clf_smoteenn = RandomForestClassifier(random_state=42)
    clf_smoteenn.fit(X_train_smoteenn, y_train_smoteenn)
    y_pred_smoteenn = clf_smoteenn.predict(X_test)
    print("Resultados para SMOTEENN:")
    print(classification_report(y_test, y_pred_smoteenn))
except Exception as e:
    print(f"Error al aplicar SMOTEENN: {e}")
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Cargar el dataset
file_path = 'winequality-white.csv'
try:
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encuentra en la ruta especificada.")
    raise
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    raise

# Verificar las primeras filas del dataset
print(pddf.head())

# Verificar las columnas del DataFrame
print("Columnas del DataFrame:", pddf.columns)

# Visualizar la distribución de la variable objetivo 'quality' en el dataset original
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='quality', data=pddf, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Original')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Separar características y etiquetas
X = pddf.drop('quality', axis=1)
y = pddf['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba con estratificación
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Verificar la distribución de la variable objetivo 'quality' en el conjunto de entrenamiento
plt.figure(figsize=(10, 6))
ax = sns.countplot(x=y_train, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Entrenamiento Original')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Verificar la distribución de la variable objetivo 'quality' en el conjunto de entrenamiento después de SMOTE
plt.figure(figsize=(10, 6))
ax = sns.countplot(x=y_train_smote, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Entrenamiento SMOTE')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Guardar los datos balanceados en un archivo CSV
balanced_data = pd.concat([pd.DataFrame(X_train_smote, columns=X.columns), pd.DataFrame(y_train_smote, columns=['quality'])], axis=1)
balanced_data.to_csv('wine-quality-white-balanced.csv', index=False)
print("Datos balanceados guardados en 'wine-quality-white-balanced.csv'")

# Entrenar el modelo con datos balanceados usando SMOTE
clf_smote = RandomForestClassifier(random_state=42)
clf_smote.fit(X_train_smote, y_train_smote)

# Predecir y evaluar el modelo balanceado con SMOTE
y_pred_smote = clf_smote.predict(X_test)
print("Resultados para SMOTE:")
print(classification_report(y_test, y_pred_smote))
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Cargar el dataset
file_path = 'winequality-white.csv'
try:
    pddf = pd.read_csv(file_path, delimiter=';')
    print("Dataset cargado correctamente.")
except FileNotFoundError:
    print(f"Error: El archivo '{file_path}' no se encuentra en la ruta especificada.")
    raise
except Exception as e:
    print(f"Error al cargar el archivo: {e}")
    raise

# Verificar las primeras filas del dataset
print(pddf.head())

# Verificar las columnas del DataFrame
print("Columnas del DataFrame:", pddf.columns)

# Verificar si hay valores NaN
print("Valores NaN en el dataset:\n", pddf.isna().sum())

# Eliminar filas con valores NaN (si es necesario)
pddf = pddf.dropna()

# Verificar que todas las columnas sean numéricas
print("Tipos de datos en el DataFrame:\n", pddf.dtypes)

# Visualizar la distribución de la variable objetivo 'quality' en el dataset original
sns.set(style="whitegrid", color_codes=True)
sns.set(rc={'figure.figsize': (10, 6)})

plt.figure(figsize=(10, 6))
ax = sns.countplot(x='quality', data=pddf, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Original')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Separar características y etiquetas
X = pddf.drop('quality', axis=1)
y = pddf['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba con estratificación
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Verificar la distribución de la variable objetivo 'quality' en el conjunto de entrenamiento
plt.figure(figsize=(10, 6))
ax = sns.countplot(x=y_train, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Entrenamiento Original')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Ajustar k_neighbors basado en el número de muestras en la clase minoritaria más pequeña
minority_class_count = y_train.value_counts().min()
k_neighbors = min(5, minority_class_count - 1)
print(f"Usando k_neighbors={k_neighbors} para SMOTE")

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Verificar la distribución de la variable objetivo 'quality' en el conjunto de entrenamiento después de SMOTE
plt.figure(figsize=(10, 6))
ax = sns.countplot(x=y_train_smote, palette='hls')

# Añadir etiquetas de conteo encima de las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', color='black')

plt.title('Distribución de la Calidad del Vino Blanco - Entrenamiento SMOTE')
plt.xlabel('Quality')
plt.ylabel('Frecuencia')
plt.show()

# Guardar los datos balanceados en un archivo CSV
balanced_data = pd.concat([pd.DataFrame(X_train_smote, columns=X.columns), pd.DataFrame(y_train_smote, columns=['quality'])], axis=1)
balanced_data.to_csv('wine-quality-white-balanced.csv', index=False)
print("Datos balanceados guardados en 'wine-quality-white-balanced.csv'")

# Entrenar el modelo con datos balanceados usando SMOTE
clf_smote = RandomForestClassifier(random_state=42)
clf_smote.fit(X_train_smote, y_train_smote)

# Predecir y evaluar el modelo balanceado con SMOTE
y_pred_smote = clf_smote.predict(X_test)
print("Resultados para SMOTE:")
print(classification_report(y_test, y_pred_smote))
# Out:
# Dataset cargado correctamente.
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# Cargar el dataset balanceado
file_path = 'wine-quality-white-balanced.csv'
balanced_data = pd.read_csv(file_path)

# Separar características y etiquetas
X = balanced_data.drop('quality', axis=1)
y = balanced_data['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir el modelo
clf = DecisionTreeClassifier(random_state=42)

# Definir los parámetros para la búsqueda
param_grid = {
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Crear el objeto GridSearchCV
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

# Entrenar el modelo usando la búsqueda de hiperparámetros
grid_search.fit(X_train, y_train)

# Mejor estimador
best_clf = grid_search.best_estimator_

# Predecir y evaluar el modelo con los mejores hiperparámetros
y_pred_best = best_clf.predict(X_test)
print("Mejores Hiperparámetros encontrados por Grid Search:")
print(grid_search.best_params_)
print("Resultados con los mejores hiperparámetros:")
print(classification_report(y_test, y_pred_best))
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# Mejores Hiperparámetros encontrados por Grid Search:
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Resultados con los mejores hiperparámetros:
#               precision    recall  f1-score   support
#
#            3       0.93      0.97      0.95       461
#            4       0.84      0.86      0.85       461
#            5       0.63      0.64      0.63       461
#            6       0.56      0.49      0.52       462
#            7       0.71      0.69      0.70       462
#            8       0.82      0.88      0.85       461
#            9       1.00      1.00      1.00       462
#
#     accuracy                           0.79      3230
#    macro avg       0.78      0.79      0.79      3230
# weighted avg       0.78      0.79      0.79      3230

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn import tree

# Cargar el dataset balanceado
file_path = 'wine-quality-white-balanced.csv'
balanced_data = pd.read_csv(file_path)

# Separar características y etiquetas
X = balanced_data.drop('quality', axis=1)
y = balanced_data['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir el modelo con los parámetros especificados
clf = DecisionTreeClassifier(max_depth=20, min_samples_leaf=1, min_samples_split=2, random_state=42)

# Entrenar el modelo
clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = clf.predict(X_test)
print("Resultados del Árbol de Decisión con los Parámetros Especificados:")
print(classification_report(y_test, y_pred))

# Visualización del árbol de decisión
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, feature_names=X.columns, class_names=[str(i) for i in clf.classes_], rounded=True, fontsize=10)
plt.show()
# Out:
# Resultados del Árbol de Decisión con los Parámetros Especificados:
#               precision    recall  f1-score   support
#
#            3       0.93      0.97      0.95       461
#            4       0.84      0.86      0.85       461
#            5       0.63      0.64      0.63       461
#            6       0.56      0.49      0.52       462
#            7       0.71      0.69      0.70       462
#            8       0.82      0.88      0.85       461
#            9       1.00      1.00      1.00       462
#
#     accuracy                           0.79      3230
#    macro avg       0.78      0.79      0.79      3230
# weighted avg       0.78      0.79      0.79      3230

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn import tree

# Cargar el dataset balanceado
file_path = 'wine-quality-white-balanced.csv'
balanced_data = pd.read_csv(file_path)

# Separar características y etiquetas
X = balanced_data.drop('quality', axis=1)
y = balanced_data['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba
# El parámetro random_state asegura que la división sea reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42, stratify=y)

# Definir el modelo con los parámetros especificados y random_state
# El parámetro random_state asegura que el modelo inicializado sea el mismo en cada ejecución
clf = DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100, random_state=123)

# Entrenar el modelo
clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = clf.predict(X_test)
print("Resultados del Árbol de Decisión con Parámetros Ajustados:")
print(classification_report(y_test, y_pred))

# Visualización del árbol de decisión
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, feature_names=X.columns, class_names=[str(i) for i in clf.classes_], rounded=True, fontsize=10)
plt.show()
# Out:
# Resultados del Árbol de Decisión con Parámetros Ajustados:
#               precision    recall  f1-score   support
#
#            3       0.53      0.47      0.50       615
#            4       0.44      0.68      0.54       615
#            5       0.35      0.35      0.35       615
#            6       0.35      0.33      0.34       616
#            7       0.35      0.22      0.27       615
#            8       0.58      0.53      0.56       615
#            9       0.90      0.98      0.94       616
#
#     accuracy                           0.51      4307
#    macro avg       0.50      0.51      0.50      4307
# weighted avg       0.50      0.51      0.50      4307

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn import tree

# Cargar el dataset balanceado
file_path = 'wine-quality-white-balanced.csv'
balanced_data = pd.read_csv(file_path)

# Separar características y etiquetas
X = balanced_data.drop('quality', axis=1)
y = balanced_data['quality']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Definir el modelo con los parámetros especificados
clf = DecisionTreeClassifier(max_depth=5, min_samples_leaf=100, min_samples_split=100, random_state=42)

# Entrenar el modelo
clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = clf.predict(X_test)
print("Resultados del Árbol de Decisión con Parámetros Ajustados:")
print(classification_report(y_test, y_pred))

# Visualización del árbol de decisión
plt.figure(figsize=(40, 20))  # Aumentar el tamaño de la figura
tree.plot_tree(clf,
               filled=True,
               feature_names=X.columns,
               class_names=[str(i) for i in clf.classes_],
               rounded=True,
               fontsize=10,
               proportion=True)  # Ajustar para que el tamaño de los nodos sea proporcional
plt.show()
# Out:
# Resultados del Árbol de Decisión con Parámetros Ajustados:
#               precision    recall  f1-score   support
#
#            3       0.60      0.43      0.50       461
#            4       0.43      0.67      0.53       461
#            5       0.35      0.36      0.36       461
#            6       0.30      0.16      0.21       462
#            7       0.41      0.41      0.41       462
#            8       0.57      0.62      0.59       461
#            9       0.89      1.00      0.94       462
#
#     accuracy                           0.52      3230
#    macro avg       0.51      0.52      0.50      3230
# weighted avg       0.51      0.52      0.50      3230

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=4)
X_smote, y_smote = smote.fit_resample(X, y)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Definir el modelo de regresión lineal
lr_clf = LinearRegression()

# Entrenar el modelo
lr_clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = lr_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2 Score:", r2)

# Visualización de las predicciones vs. valores reales
plt.scatter(y_test, y_pred)
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Predicciones vs. Valores Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.show()
# Out:
# Mean Squared Error (MSE): 2.2428451309339392
# R^2 Score: 0.43668828445122565

# %%
import pandas as pd

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Mostrar los nombres de las columnas
print("Columnas del DataFrame:", data.columns)
# Out:
# Columnas del DataFrame: Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Verificar los nombres de las columnas
print("Columnas del DataFrame:", data.columns)

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=2)
X_smote, y_smote = smote.fit_resample(X, y)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Definir el modelo de regresión lineal
lr_clf = LinearRegression()

# Entrenar el modelo
lr_clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = lr_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2 Score:", r2)

# Visualización de las predicciones vs. valores reales
plt.scatter(y_test, y_pred)
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Predicciones vs. Valores Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.show()
# Out:
# Columnas del DataFrame: Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# Mean Squared Error (MSE): 2.222375274450242
# R^2 Score: 0.4418294820371985

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Crear nuevas características
data['free_sulfur_ratio'] = data['free sulfur dioxide'] / data['total sulfur dioxide']
data['density_alcohol'] = data['density'] * data['alcohol']
data['sulfur_ratio'] = data['free sulfur dioxide'] / (data['chlorides'] + 1)  # Evitar división por cero

# Guardar el nuevo dataset con las características agregadas
new_file_path = 'winequality-white-with-new-features.csv'
data.to_csv(new_file_path, index=False)

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=2)
X_smote, y_smote = smote.fit_resample(X, y)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Definir los modelos de regresión
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.1)
}

# Entrenar y evaluar cada modelo
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    results[name] = (mse, r2)
    print(f"{name} - Mean Squared Error (MSE): {mse}, R^2 Score: {r2}")

# Visualización de las predicciones vs. valores reales para cada modelo
plt.figure(figsize=(15, 5))
for i, (name, model) in enumerate(models.items(), 1):
    y_pred = model.predict(X_test)
    plt.subplot(1, 3, i)
    plt.scatter(y_test, y_pred)
    plt.xlabel("Valores Reales")
    plt.ylabel("Predicciones")
    plt.title(f"{name}")
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.tight_layout()
plt.show()
# Out:
# Linear Regression - Mean Squared Error (MSE): 1.970401403091418, R^2 Score: 0.505115097165471
# Ridge Regression - Mean Squared Error (MSE): 2.048508267254449, R^2 Score: 0.4854978213041232
# Lasso Regression - Mean Squared Error (MSE): 2.6528360685321015, R^2 Score: 0.3337151922691093

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Aplicar transformaciones logarítmicas
data['log_fixed_acidity'] = np.log1p(data['fixed acidity'])  # log1p se usa para evitar log(0)
data['log_volatile_acidity'] = np.log1p(data['volatile acidity'])
data['log_citric_acid'] = np.log1p(data['citric acid'])
data['log_residual_sugar'] = np.log1p(data['residual sugar'])
data['log_chlorides'] = np.log1p(data['chlorides'])
data['log_free_sulfur_dioxide'] = np.log1p(data['free sulfur dioxide'])
data['log_total_sulfur_dioxide'] = np.log1p(data['total sulfur dioxide'])
data['log_density'] = np.log1p(data['density'])
data['log_pH'] = np.log1p(data['pH'])
data['log_sulphates'] = np.log1p(data['sulphates'])
data['log_alcohol'] = np.log1p(data['alcohol'])

# Guardar el nuevo dataset con las características transformadas
new_file_path = 'winequality-white-with-log-features.csv'
data.to_csv(new_file_path, index=False)

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=2)
X_smote, y_smote = smote.fit_resample(X, y)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Definir el modelo de regresión lineal
lr_clf = LinearRegression()

# Entrenar el modelo
lr_clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = lr_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2 Score:", r2)

# Visualización de las predicciones vs. valores reales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Regresión Lineal - Predicciones vs. Valores Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.show()
# Out:
# Mean Squared Error (MSE): 1.5609874207438095
# R^2 Score: 0.6079432815929227

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Crear nuevas características
data['free_sulfur_ratio'] = data['free sulfur dioxide'] / data['total sulfur dioxide']
data['density_alcohol'] = data['density'] * data['alcohol']
data['sulfur_ratio'] = data['free sulfur dioxide'] / (data['chlorides'] + 1)  # Evitar división por cero

# Aplicar transformaciones logarítmicas
data['log_fixed_acidity'] = np.log1p(data['fixed acidity'])  # log1p se usa para evitar log(0)
data['log_volatile_acidity'] = np.log1p(data['volatile acidity'])
data['log_citric_acid'] = np.log1p(data['citric acid'])
data['log_residual_sugar'] = np.log1p(data['residual sugar'])
data['log_chlorides'] = np.log1p(data['chlorides'])
data['log_free_sulfur_dioxide'] = np.log1p(data['free sulfur dioxide'])
data['log_total_sulfur_dioxide'] = np.log1p(data['total sulfur dioxide'])
data['log_density'] = np.log1p(data['density'])
data['log_pH'] = np.log1p(data['pH'])
data['log_sulphates'] = np.log1p(data['sulphates'])
data['log_alcohol'] = np.log1p(data['alcohol'])

# Guardar el nuevo dataset con las características agregadas y transformadas
new_file_path = 'winequality-white-with-new-features-log.csv'
data.to_csv(new_file_path, index=False)

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=2)
X_smote, y_smote = smote.fit_resample(X, y)

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Definir el modelo de regresión lineal
lr_clf = LinearRegression()

# Entrenar el modelo
lr_clf.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = lr_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R^2 Score:", r2)

# Visualización de las predicciones vs. valores reales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Regresión Lineal - Predicciones vs. Valores Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.show()
# Out:
# Mean Squared Error (MSE): 1.5231142021082635
# R^2 Score: 0.6174554977815008

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, make_scorer
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE

# Cargar el dataset original
file_path = 'winequality-white.csv'
data = pd.read_csv(file_path, sep=';')

# Crear nuevas características
data['free_sulfur_ratio'] = data['free sulfur dioxide'] / data['total sulfur dioxide']
data['density_alcohol'] = data['density'] * data['alcohol']
data['sulfur_ratio'] = data['free sulfur dioxide'] / (data['chlorides'] + 1)  # Evitar división por cero

# Aplicar transformaciones logarítmicas
data['log_fixed_acidity'] = np.log1p(data['fixed acidity'])  # log1p se usa para evitar log(0)
data['log_volatile_acidity'] = np.log1p(data['volatile acidity'])
data['log_citric_acid'] = np.log1p(data['citric acid'])
data['log_residual_sugar'] = np.log1p(data['residual sugar'])
data['log_chlorides'] = np.log1p(data['chlorides'])
data['log_free_sulfur_dioxide'] = np.log1p(data['free sulfur dioxide'])
data['log_total_sulfur_dioxide'] = np.log1p(data['total sulfur dioxide'])
data['log_density'] = np.log1p(data['density'])
data['log_pH'] = np.log1p(data['pH'])
data['log_sulphates'] = np.log1p(data['sulphates'])
data['log_alcohol'] = np.log1p(data['alcohol'])

# Guardar el nuevo dataset con las características agregadas y transformadas
new_file_path = 'winequality-white-with-new-features-log.csv'
data.to_csv(new_file_path, index=False)

# Separar características y etiquetas
X = data.drop('quality', axis=1)
y = data['quality']

# Aplicar SMOTE para balancear el conjunto de entrenamiento
smote = SMOTE(random_state=42, k_neighbors=2)
X_smote, y_smote = smote.fit_resample(X, y)

# Definir el modelo de regresión lineal
lr_clf = LinearRegression()

# Validación cruzada
kf = KFold(n_splits=10, shuffle=True, random_state=42)
mse_scores = cross_val_score(lr_clf, X_smote, y_smote, scoring=make_scorer(mean_squared_error), cv=kf)
r2_scores = cross_val_score(lr_clf, X_smote, y_smote, scoring='r2', cv=kf)

print("Mean Squared Error (MSE) - Cross-Validation:", mse_scores.mean())
print("R^2 Score - Cross-Validation:", r2_scores.mean())

# Entrenar el modelo en todo el conjunto de datos de entrenamiento
lr_clf.fit(X_smote, y_smote)

# Dividir los datos en conjuntos de entrenamiento y prueba para visualización final
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size=0.3, random_state=42)

# Predecir y evaluar el modelo
y_pred = lr_clf.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE) - Test:", mse)
print("R^2 Score - Test:", r2)

# Visualización de las predicciones vs. valores reales
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.xlabel("Valores Reales")
plt.ylabel("Predicciones")
plt.title("Regresión Lineal - Predicciones vs. Valores Reales")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Línea de identidad
plt.show()
# Out:
# Mean Squared Error (MSE) - Cross-Validation: 2.3078489053988154
# R^2 Score - Cross-Validation: 0.42060631363865
# Mean Squared Error (MSE) - Test: 1.5176994885533241
# R^2 Score - Test: 0.6188154541778517

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# Paso 1: Cargar el dataset original
data = pd.read_csv('winequality-white.csv', delimiter=';')

# Separar las características (X) y el objetivo (y)
X = data.drop('quality', axis=1)
y = data['quality']

# Verificar la distribución de las clases antes de SMOTE
print("Distribución de las clases antes de SMOTE:")
print(y.value_counts())

# Paso 2: Aplicar SMOTE con menos vecinos
smote = SMOTE(random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Verificar la distribución de las clases después de SMOTE
print("Distribución de las clases después de SMOTE:")
print(y_resampled.value_counts())

# Paso 3: Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir el objetivo a categorías
y_train_cat = to_categorical(y_train - y_train.min())
y_test_cat = to_categorical(y_test - y_test.min())

# Paso 4: Construir el modelo de red neuronal
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(y_train_cat.shape[1], activation='softmax', kernel_regularizer=l2(0.01)))

# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=32, validation_data=(X_test, y_test_cat), verbose=0)

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Visualización de los resultados

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# Distribución de las clases antes de SMOTE:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64
# Distribución de las clases después de SMOTE:
# quality
# 6    2198
# 5    2198
# 7    2198
# 8    2198
# 4    2198
# 3    2198
# 9    2198
# Name: count, dtype: int64
# Loss: 0.9019404053688049, Accuracy: 0.6562703251838684

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# Paso 1: Cargar el dataset original
data = pd.read_csv('winequality-white.csv', delimiter=';')

# Separar las características (X) y el objetivo (y)
X = data.drop('quality', axis=1)
y = data['quality']

# Verificar la distribución de las clases antes de SMOTE
print("Distribución de las clases antes de SMOTE:")
print(y.value_counts())

# Paso 2: Aplicar SMOTE con menos vecinos
smote = SMOTE(random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Verificar la distribución de las clases después de SMOTE
print("Distribución de las clases después de SMOTE:")
print(y_resampled.value_counts())

# Paso 3: Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir el objetivo a categorías
y_train_cat = to_categorical(y_train - y_train.min())
y_test_cat = to_categorical(y_test - y_test.min())

# Paso 4: Construir el modelo de red neuronal mejorado
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))  # Ajuste del Dropout

model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(y_train_cat.shape[1], activation='softmax', kernel_regularizer=l2(0.01)))

# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=32, validation_data=(X_test, y_test_cat), verbose=1)

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Visualización de los resultados

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# Distribución de las clases antes de SMOTE:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64
# Distribución de las clases después de SMOTE:
# quality
# 6    2198
# 5    2198
# 7    2198
# 8    2198
# 4    2198
# 3    2198
# 9    2198
# Name: count, dtype: int64
# Epoch 1/100
# 385/385 [==============================] - 9s 8ms/step - loss: 3.1129 - accuracy: 0.3580 - val_loss: 2.3114 - val_accuracy: 0.5676
# Epoch 2/100
# 385/385 [==============================] - 2s 5ms/step - loss: 2.1909 - accuracy: 0.4708 - val_loss: 1.7446 - val_accuracy: 0.6053
# Epoch 3/100
# 385/385 [==============================] - 1s 4ms/step - loss: 1.7295 - accuracy: 0.5124 - val_loss: 1.4056 - val_accuracy: 0.6342
# Epoch 4/100
# 385/385 [==============================] - 2s 5ms/step - loss: 1.4471 - accuracy: 0.5535 - val_loss: 1.2060 - val_accuracy: 0.6241
# Epoch 5/100
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# Paso 1: Cargar el dataset original
data = pd.read_csv('winequality-white.csv', delimiter=';')

# Separar las características (X) y el objetivo (y)
X = data.drop('quality', axis=1)
y = data['quality']

# Verificar la distribución de las clases antes de SMOTE
print("Distribución de las clases antes de SMOTE:")
print(y.value_counts())

# Paso 2: Aplicar SMOTE con menos vecinos
smote = SMOTE(random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Verificar la distribución de las clases después de SMOTE
print("Distribución de las clases después de SMOTE:")
print(y_resampled.value_counts())

# Paso 3: Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir el objetivo a categorías
y_train_cat = to_categorical(y_train - y_train.min())
y_test_cat = to_categorical(y_test - y_test.min())

# Paso 4: Construir el modelo de red neuronal mejorado
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))  # Ajuste del Dropout

model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))  # Capa adicional
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Dense(y_train_cat.shape[1], activation='softmax', kernel_regularizer=l2(0.01)))

# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=32, validation_data=(X_test, y_test_cat), verbose=1)

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Visualización de los resultados

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# Distribución de las clases antes de SMOTE:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64
# Distribución de las clases después de SMOTE:
# quality
# 6    2198
# 5    2198
# 7    2198
# 8    2198
# 4    2198
# 3    2198
# 9    2198
# Name: count, dtype: int64
# Epoch 1/100
# 385/385 [==============================] - 20s 23ms/step - loss: 3.2249 - accuracy: 0.3499 - val_loss: 2.5306 - val_accuracy: 0.5055
# Epoch 2/100
# 385/385 [==============================] - 4s 12ms/step - loss: 2.2996 - accuracy: 0.4603 - val_loss: 1.8480 - val_accuracy: 0.5747
# Epoch 3/100
# 385/385 [==============================] - 5s 12ms/step - loss: 1.7917 - accuracy: 0.5146 - val_loss: 1.4879 - val_accuracy: 0.6105
# Epoch 4/100
# 385/385 [==============================] - 4s 10ms/step - loss: 1.4847 - accuracy: 0.5513 - val_loss: 1.2392 - val_accuracy: 0.6511
# Epoch 5/100
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
import matplotlib.pyplot as plt

# Paso 1: Cargar el dataset original
data = pd.read_csv('winequality-white.csv', delimiter=';')

# Separar las características (X) y el objetivo (y)
X = data.drop('quality', axis=1)
y = data['quality']

# Verificar la distribución de las clases antes de SMOTE
print("Distribución de las clases antes de SMOTE:")
print(y.value_counts())

# Paso 2: Aplicar SMOTE con menos vecinos
smote = SMOTE(random_state=42, k_neighbors=3)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Verificar la distribución de las clases después de SMOTE
print("Distribución de las clases después de SMOTE:")
print(y_resampled.value_counts())

# Paso 3: Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir el objetivo a categorías
y_train_cat = to_categorical(y_train - y_train.min())
y_test_cat = to_categorical(y_test - y_test.min())

# Paso 4: Construir el modelo de red neuronal mejorado
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(y_train_cat.shape[1], activation='softmax', kernel_regularizer=l2(0.01)))

# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Entrenar el modelo
history = model.fit(X_train, y_train_cat, epochs=100, batch_size=32, validation_data=(X_test, y_test_cat), verbose=1)

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test_cat, verbose=0)
print(f'Loss: {loss}, Accuracy: {accuracy}')

# Visualización de los resultados

# Plot training & validation accuracy values
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()
# Out:
# Distribución de las clases antes de SMOTE:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64
# Distribución de las clases después de SMOTE:
# quality
# 6    2198
# 5    2198
# 7    2198
# 8    2198
# 4    2198
# 3    2198
# 9    2198
# Name: count, dtype: int64
# Epoch 1/100
# 385/385 [==============================] - 10s 7ms/step - loss: 3.5275 - accuracy: 0.2562 - val_loss: 2.7615 - val_accuracy: 0.4327
# Epoch 2/100
# 385/385 [==============================] - 2s 4ms/step - loss: 2.5579 - accuracy: 0.3972 - val_loss: 2.0554 - val_accuracy: 0.5630
# Epoch 3/100
# 385/385 [==============================] - 2s 5ms/step - loss: 1.9832 - accuracy: 0.4607 - val_loss: 1.6256 - val_accuracy: 0.5949
# Epoch 4/100
# 385/385 [==============================] - 2s 5ms/step - loss: 1.6513 - accuracy: 0.4998 - val_loss: 1.3599 - val_accuracy: 0.6108
# Epoch 5/100
# ...
